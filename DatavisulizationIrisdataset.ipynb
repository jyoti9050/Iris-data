# %%
import pandas as pd
import numpy as np
iris=pd.read_csv("Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
#see how many no of species are there and what kind of species are there to dealth with 
iris['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
#complete statstics 
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #   Draw a plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
iris.plot(color="green")    ##plots all the columns against index


#label the axes and title 
plt.title("Iris Data Set")

plt.xlabel("Features")
plt.ylabel("Targets")

#location of legend
plt.legend(loc=1)  
plt.show()

# %%
#features data 
features=iris.iloc[: , [0,1,2,3]]
features
plt.plot(features)

# %%
#features data 
features=iris.iloc[: , [0,1,2,3]]
features

#extract the values of target 
targetsall=[]
targets=iris.iloc[:,0]
plt.plot(features,targets,color='green')

plt.legend()
plt.show()
